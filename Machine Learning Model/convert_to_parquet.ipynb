# %% [markdown]
# Este código está comentado debido a que ya se usó. No hace falta tenerlo activo pues interrumpe la ejecución en Render

# %%
# import pandas as pd
# import pyarrow as pa
# import pyarrow.parquet as pq

# %%
# movies = pd.read_csv('movies_dataset_cleaned.csv')
# actors = pd.read_csv('actors.csv',compression='gzip')
# crew = pd.read_csv('crew.csv',compression='gzip')
# ml_dataset = pd.read_csv('final_movie_set.csv', compression='gzip')

# %%
# def convert_to_parquet(input_file, outout_file):
#   # take the dataframe and checks if there if something to drop
#   # Convert Pandas DataFrame to PyArrow Table
#   table = pa.Table.from_pandas(input_file)
#   # Write PyArrow Table to Parquet file
#   pq.write_table(table, outout_file,compression='gzip')
#   # Open the Parquet file
#   table = pq.read_table(outout_file)
#   # Convert the table to a Pandas DataFrame
#   df = table.to_pandas()
#   # Print the DataFrame
#   print(df.head(100))

# %%
# convert_to_parquet(movies,'movies_dataset_cleaned.parquet')
# Out:
#       budget     id original_language  \
# 0   30000000    862                en
# 1   65000000   8844                en
# 2          0  15602                en
# 3   16000000  31357                en
# 4          0  11862                en
# ..       ...    ...               ...
# 95   3000000    406                fr
# 96         0  45549                en
# 97         0  63076                en
# 98         0  11062                en
# 99   7000000  13685                en
#
#                                              overview  popularity  \
# 0   Led by Woody, Andy's toys live happily in his ...   21.946943
# 1   When siblings Judy and Peter discover an encha...   17.015539
# 2   A family wedding reignites the ancient feud be...   11.712900
# 3   Cheated on, mistreated and stepped on, the wom...    3.859495
# 4   Just when George Banks has recovered from his ...    8.387519
# ..                                                ...         ...
# ...

# %%
# convert_to_parquet(actors,'actors.parquet')
# Out:
#      id  cast_id                character                 credit_id  \
# 0   862     14.0            Woody (voice)  52fe4284c3a36847f8024f95
# 1   862     15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2   862     16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3   862     17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4   862     18.0              Rex (voice)  52fe4284c3a36847f8024fa5
# ..  ...      ...                      ...                       ...
# 95  949     52.0          Hooker's Mother  52fe4292c3a36847f8029263
# 96  949     53.0                  Timmons  52fe4292c3a36847f8029267
# 97  949     59.0      Shooter at Drive-in  52fe4292c3a36847f802927f
# 98  949     60.0       Driver at Drive-in  52fe4292c3a36847f8029283
# 99  949     96.0            Officer Bruce  56be773e9251417359005063
#
#     actor_gender  actor_id          actor_name  order  \
# 0            2.0      31.0           Tom Hanks    0.0
# ...

# %%
# convert_to_parquet(crew,'crew.parquet')
# Out:
#      id            crew_credit_id crew_department  crew_gender    crew_id  \
# 0   862  52fe4284c3a36847f8024f49       Directing          2.0     7879.0
# 1   862  52fe4284c3a36847f8024f4f         Writing          2.0    12891.0
# 2   862  52fe4284c3a36847f8024f55         Writing          2.0        7.0
# 3   862  52fe4284c3a36847f8024f5b         Writing          2.0    12892.0
# 4   862  52fe4284c3a36847f8024f61         Writing          0.0    12893.0
# ..  ...                       ...             ...          ...        ...
# 95  862  58921544c3a3686b0a00507d           Sound          2.0     2216.0
# 96  862  5892154c9251412dd1009a56           Sound          0.0  1425978.0
# 97  862  58921555c3a36809680091bd           Sound          2.0     8276.0
# 98  862  589215c39251412dcb009c12           Sound          0.0     7069.0
# 99  862  58921698c3a368096a009788            Crew          2.0    15894.0
#
#                     crew_job       crew_name                 crew_profile_path
# ...

# %%
# convert_to_parquet(ml_dataset,'final_movie_set.parquet')
# Out:
#     Unnamed: 0 original_language  \
# 0            0                en
# 1            1                en
# 2            2                en
# 3            3                en
# 4            4                en
# ..         ...               ...
# 95          95                fr
# 96          96                en
# 97          97                en
# 98          98                en
# 99          99                en
#
#                                              overview  popularity  \
# 0   Led by Woody, Andy's toys live happily in his ...   21.946943
# 1   When siblings Judy and Peter discover an encha...   17.015539
# 2   A family wedding reignites the ancient feud be...   11.712900
# 3   Cheated on, mistreated and stepped on, the wom...    3.859495
# 4   Just when George Banks has recovered from his ...    8.387519
# ..                                                ...         ...
# 95  Aimlessly whiling away their days in the concr...   12.108196
# ...

# %% [markdown]
# Ahora se intentan leer los archivos convertidos a `.parquet`

# %%
# movies_parquet = pd.read_parquet('actors.parquet', engine='pyarrow')
# movies_parquet.head(10)
# Out:
#     id  cast_id                character                 credit_id  \
# 0  862     14.0            Woody (voice)  52fe4284c3a36847f8024f95
# 1  862     15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2  862     16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3  862     17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4  862     18.0              Rex (voice)  52fe4284c3a36847f8024fa5
# 5  862     19.0             Hamm (voice)  52fe4284c3a36847f8024fa9
# 6  862     20.0          Bo Peep (voice)  52fe4284c3a36847f8024fad
# 7  862     26.0             Andy (voice)  52fe4284c3a36847f8024fc1
# 8  862     22.0              Sid (voice)  52fe4284c3a36847f8024fb1
# 9  862     23.0       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5
#
#    actor_gender   actor_id         actor_name  order  \
# 0           2.0       31.0          Tom Hanks    0.0
# 1           2.0    12898.0          Tim Allen    1.0
# 2           2.0     7167.0        Don Rickles    2.0
# ...
